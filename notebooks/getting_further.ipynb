# %% [markdown]
# # Complete study with Salome
#
# ## Introduction: non-stationary 3D diffusion
#
# In this new example, we're trying to solve an unsteady problem,
# i.e. with a temporal evolution of the solution.
#
# The diffusion equation is again considered:
#
# $$
# \rho c_p \frac{partial T}{partial t} - \lambda\Delta T = \Phi
# $$
#
# We begin by creating the geometry and mesh with Salome.
#
# ## Preparing the mesh

# %%
import cdmath
import CoreFlows as cf
from math import exp

import salome
#salome.salome_init()

#import pvsimple
#pvsimple.ShowParaviewView()
from pvsimple import *
#pvsimple._DisableFirstRenderCameraReset()
# Out:
# Waiting for client...
# Connection URL: cs://is245202:11111
# Accepting connection(s): is245202:11111
# Client connected.
# level=Info msg=Meshing 1D...
# level=Info msg=Meshing curve 2 (Circle)
# level=Progress msg=Meshing 1D...
# level=Progress msg=Meshing 1D...
# level=Info msg=Done meshing 1D (Wall 0.000506013s, CPU 0.000383s)
# level=Info msg=33 nodes 34 elements
# level=Info msg=Meshing 2D...
# level=Info msg=Meshing surface 1 (Sphere, MeshAdapt)
# level=Progress msg=Meshing 2D...
# level=Info msg=Done meshing 2D (Wall 0.315839s, CPU 0.42227s)
# level=Info msg=1733 nodes 3496 elements
# level=Warning msg=Converged at iter. 8 for initial guess (0,0) with uv error = 2.20527e-07, but xyz error = 0.000396583 in point (4.291168e-01, -5.424566e-01, -7.222186e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,1) with uv error = 2.48257e-07, but xyz error = 0.000423993 in point (4.880123e-01, -4.723497e-01, -7.339822e-01) on surface 1
# level=Warning msg=Converged at iter. 9 for initial guess (0,2) with uv error = 2.43564e-07, but xyz error = 0.000418273 in point (1.412393e-01, -1.526415e-01, 9.781370e-01) on surface 1
# level=Warning msg=Converged at iter. 8 for initial guess (0,0) with uv error = 1.70275e-07, but xyz error = 0.000412642 in point (9.861579e-01, -1.653665e-01, 1.210098e-02) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.18937e-07, but xyz error = 0.000348044 in point (-2.116511e-01, 4.497731e-01, 8.677027e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 2.85368e-07, but xyz error = 0.000366956 in point (-1.804612e-01, 5.075198e-01, 8.425303e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.70653e-07, but xyz error = 0.000488278 in point (-4.044234e-01, 1.105957e-01, -9.078603e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 3.79808e-07, but xyz error = 0.000608762 in point (-8.096251e-01, 4.489782e-01, 3.780553e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 1.6648e-07, but xyz error = 0.000373795 in point (1.743129e-01, -7.912481e-01, 5.861241e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 4.31515e-07, but xyz error = 0.000605056 in point (2.544079e-01, -7.974197e-01, 5.471731e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 1.77644e-07, but xyz error = 0.000362288 in point (5.080777e-01, 6.630101e-01, -5.497950e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 3.19859e-07, but xyz error = 0.000564679 in point (-7.737449e-01, 5.697714e-01, 2.769104e-01) on surface 1
# level=Warning msg=Converged at iter. 8 for initial guess (0,1) with uv error = 1.46755e-07, but xyz error = 0.00037328 in point (9.272440e-01, 2.145482e-01, -3.069001e-01) on surface 1
# level=Warning msg=Converged at iter. 3 for initial guess (0,0) with uv error = 2.40723e-07, but xyz error = 0.000490452 in point (-9.901002e-01, -1.376758e-01, -2.732960e-02) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.65692e-07, but xyz error = 0.000576829 in point (5.112039e-01, 7.925187e-01, 3.325426e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 1.92941e-07, but xyz error = 0.000415928 in point (4.293435e-01, 8.192615e-01, 3.800984e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.02473e-07, but xyz error = 0.00041632 in point (-1.514746e-01, -9.074436e-01, 3.919203e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 4.2179e-07, but xyz error = 0.000587026 in point (1.476961e-01, 7.623322e-01, -6.301075e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 2.30042e-07, but xyz error = 0.000479412 in point (7.656070e-01, -6.402633e-01, -6.251979e-02) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.44604e-07, but xyz error = 0.000587028 in point (8.085650e-01, -5.884028e-01, 2.198804e-03) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.37463e-07, but xyz error = 0.000487006 in point (-7.557355e-01, 6.175913e-01, -2.178183e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.77327e-07, but xyz error = 0.000404159 in point (-4.871672e-01, 2.004265e-01, 8.499984e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 1.63116e-07, but xyz error = 0.000395907 in point (1.388637e-02, 9.746621e-01, 2.232511e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 1.97209e-07, but xyz error = 0.000396417 in point (-2.261773e-01, 8.578726e-01, -4.614092e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 1.67821e-07, but xyz error = 0.00039368 in point (-6.175607e-02, 9.537761e-01, 2.941042e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.44716e-07, but xyz error = 0.000395323 in point (-7.952515e-01, 6.133259e-02, 6.031694e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.89746e-07, but xyz error = 0.000435484 in point (-5.936536e-01, -8.042778e-01, 2.669476e-02) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 2.89025e-07, but xyz error = 0.000353021 in point (-1.960545e-01, -4.823693e-01, 8.537462e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 1.78536e-07, but xyz error = 0.000405373 in point (5.229422e-01, -7.954811e-01, -3.061722e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 2.52335e-07, but xyz error = 0.000477493 in point (4.702560e-01, -8.082148e-01, -3.544687e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.80542e-07, but xyz error = 0.000587017 in point (4.959282e-01, -7.968029e-01, 3.451961e-01) on surface 1
# level=Warning msg=Converged at iter. 8 for initial guess (0,0) with uv error = 1.75606e-07, but xyz error = 0.000390656 in point (8.649400e-01, -3.398202e-01, -3.693251e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 2.06169e-07, but xyz error = 0.000449116 in point (7.230111e-01, -6.559642e-01, 2.167163e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.92017e-07, but xyz error = 0.000622304 in point (7.349354e-01, -6.666131e-01, 1.244867e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 1.40355e-07, but xyz error = 0.000374577 in point (2.816499e-01, 9.588925e-01, 3.462003e-02) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 3.93732e-07, but xyz error = 0.000586606 in point (-9.249488e-02, -9.243994e-01, -3.700411e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 3.90842e-07, but xyz error = 0.000624774 in point (-6.255718e-01, -7.756248e-01, 8.406002e-02) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.02834e-07, but xyz error = 0.000450171 in point (-6.838707e-01, -7.218155e-01, 1.063165e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.70147e-07, but xyz error = 0.000452969 in point (-1.357929e-01, 5.581030e-01, 8.185850e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.05609e-07, but xyz error = 0.000451611 in point (-8.090010e-01, 4.942462e-01, -3.181794e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 1.51196e-07, but xyz error = 0.00038336 in point (4.075794e-02, -9.795482e-01, -1.970385e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 3.15002e-07, but xyz error = 0.000556811 in point (1.208984e-01, -9.785150e-01, -1.670089e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (2,0) with uv error = 3.13327e-07, but xyz error = 0.000532405 in point (9.049494e-01, 7.652300e-02, -4.185818e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 4.51297e-07, but xyz error = 0.000541199 in point (-3.515464e-01, -7.136402e-01, -6.059149e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 3.57859e-07, but xyz error = 0.000555672 in point (6.416378e-01, 6.179923e-01, 4.542978e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 4.27855e-07, but xyz error = 0.000634712 in point (-8.204789e-01, 3.820929e-01, -4.252286e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.49994e-07, but xyz error = 0.000473246 in point (-8.416254e-01, 2.999575e-01, -4.491014e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,4) with uv error = 4.53158e-07, but xyz error = 0.000362073 in point (7.614864e-02, -1.716201e-01, -9.822158e-01) on surface 1
# level=Warning msg=Converged at iter. 9 for initial guess (0,2) with uv error = 1.82731e-07, but xyz error = 0.000366963 in point (6.971229e-01, 3.401835e-01, 6.311061e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 1.73316e-07, but xyz error = 0.000408854 in point (8.447670e-01, -4.675816e-01, -2.602619e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 4.87052e-07, but xyz error = 0.000595583 in point (-2.574936e-01, -8.061587e-01, 5.327337e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.25613e-07, but xyz error = 0.000398489 in point (-3.274241e-01, -7.644223e-01, 5.553845e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.54447e-07, but xyz error = 0.000458136 in point (-1.788714e-01, 8.848284e-01, 4.302136e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.40877e-07, but xyz error = 0.000458438 in point (-1.204290e-01, 9.208656e-01, 3.708144e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.33705e-07, but xyz error = 0.000561873 in point (6.671504e-01, -7.033662e-01, 2.453290e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 1.79436e-07, but xyz error = 0.000389796 in point (-1.697166e-01, 8.991942e-01, -4.032940e-01) on surface 1
# level=Warning msg=Converged at iter. 8 for initial guess (0,1) with uv error = 2.08901e-07, but xyz error = 0.000433874 in point (8.760010e-01, -2.733845e-01, -3.973453e-01) on surface 1
# level=Warning msg=Converged at iter. 8 for initial guess (0,1) with uv error = 3.47038e-07, but xyz error = 0.000562874 in point (9.217174e-01, -2.137890e-01, -3.236223e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 2.98855e-07, but xyz error = 0.000528507 in point (6.041111e-01, -7.507682e-01, 2.672019e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 1.47645e-07, but xyz error = 0.00038 in point (8.729833e-01, -4.524472e-01, 1.821862e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 3.73053e-07, but xyz error = 0.000610573 in point (-5.640831e-01, -8.251577e-01, -3.041259e-02) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 3.17407e-07, but xyz error = 0.000563334 in point (9.426787e-01, -3.318057e-01, 3.552181e-02) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.15926e-07, but xyz error = 0.000461096 in point (-8.186542e-01, -4.569852e-01, -3.478072e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.93219e-07, but xyz error = 0.000360637 in point (-8.135882e-01, -7.603321e-02, -5.764488e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 4.61939e-07, but xyz error = 0.000679658 in point (7.960675e-01, 6.037926e-01, 4.136616e-02) on surface 1
# level=Warning msg=Converged at iter. 10 for initial guess (0,4) with uv error = 3.57576e-07, but xyz error = 0.000496351 in point (8.067422e-01, -6.500422e-02, 5.873172e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 1.50403e-07, but xyz error = 0.000376522 in point (7.523030e-01, 5.463645e-01, -3.681387e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 1.75496e-07, but xyz error = 0.000394032 in point (3.719133e-01, -8.252693e-01, 4.249835e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 3.29926e-07, but xyz error = 0.000574277 in point (3.126540e-01, -9.489979e-01, -4.062472e-02) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.708e-07, but xyz error = 0.000413128 in point (-7.317161e-01, 6.636809e-01, -1.553038e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.23485e-07, but xyz error = 0.000351272 in point (-6.973115e-01, 7.103955e-01, -9.536764e-02) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 3.88564e-07, but xyz error = 0.000612822 in point (7.337547e-02, -9.739174e-01, 2.147111e-01) on surface 1
# level=Warning msg=Converged at iter. 8 for initial guess (0,1) with uv error = 4.8862e-07, but xyz error = 0.000624292 in point (7.622160e-01, 3.693311e-01, -5.316214e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 1.55726e-07, but xyz error = 0.000392571 in point (7.210859e-01, -6.831781e-01, -1.153376e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 1.59114e-07, but xyz error = 0.000381928 in point (-7.598291e-02, -9.493107e-01, -3.050176e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.41819e-07, but xyz error = 0.000491504 in point (-6.648842e-01, -7.407131e-01, -9.629677e-02) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 3.04138e-07, but xyz error = 0.000443491 in point (-3.759919e-01, -6.992007e-01, 6.080694e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.05396e-07, but xyz error = 0.000449826 in point (1.033260e-01, 9.814058e-01, 1.617601e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,1) with uv error = 3.36938e-07, but xyz error = 0.00036551 in point (4.508881e-01, -3.967321e-01, -7.995646e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.71148e-07, but xyz error = 0.000377907 in point (-5.146003e-01, 2.712756e-01, 8.133856e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.86231e-07, but xyz error = 0.000475362 in point (-1.180828e-01, 5.769818e-01, -8.081760e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 4.4293e-07, but xyz error = 0.000647721 in point (-8.179427e-01, -3.927711e-01, -4.203577e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (1,1) with uv error = 1.45712e-07, but xyz error = 0.000346997 in point (7.036867e-01, -1.118296e-01, -7.016546e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 4.79491e-07, but xyz error = 0.000604399 in point (4.304024e-02, 7.047035e-01, 7.081952e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 2.66546e-07, but xyz error = 0.000412757 in point (-9.498411e-02, 6.112807e-01, 7.856933e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.89391e-07, but xyz error = 0.000414298 in point (-8.471392e-01, -3.020589e-01, -4.371678e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 2.29495e-07, but xyz error = 0.000473273 in point (8.680957e-01, 4.542626e-01, 2.001383e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 3.17913e-07, but xyz error = 0.000563596 in point (-5.795283e-01, 8.140966e-01, 3.733337e-02) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 4.77121e-07, but xyz error = 0.000655127 in point (4.822585e-01, 7.978226e-01, -3.618091e-01) on surface 1
# level=Warning msg=Converged at iter. 8 for initial guess (0,2) with uv error = 3.66212e-07, but xyz error = 0.000571352 in point (9.096269e-01, -1.998483e-01, 3.641972e-01) on surface 1
# level=Warning msg=Converged at iter. 9 for initial guess (0,1) with uv error = 2.56766e-07, but xyz error = 0.000459872 in point (7.202092e-01, 3.284353e-01, -6.110883e-01) on surface 1
# level=Warning msg=Converged at iter. 10 for initial guess (0,4) with uv error = 4.41164e-07, but xyz error = 0.000618044 in point (6.635848e-01, 1.974301e-01, 7.215792e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 4.16099e-07, but xyz error = 0.000637363 in point (7.244144e-01, 6.691285e-01, -1.658033e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 3.61418e-07, but xyz error = 0.000529176 in point (-8.326292e-01, 1.898852e-01, 5.202617e-01) on surface 1
# level=Warning msg=Converged at iter. 8 for initial guess (0,1) with uv error = 3.43167e-07, but xyz error = 0.00043731 in point (6.002251e-01, 3.969754e-01, -6.943633e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.19156e-07, but xyz error = 0.000466557 in point (-8.037481e-01, -5.072117e-01, 3.110070e-01) on surface 1
# level=Warning msg=Converged at iter. 3 for initial guess (0,0) with uv error = 3.57455e-07, but xyz error = 0.00059517 in point (-9.909351e-01, -9.095507e-02, -9.886805e-02) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 3.64817e-07, but xyz error = 0.000583644 in point (-2.660210e-03, -9.602174e-01, 2.792408e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.73516e-07, but xyz error = 0.000495612 in point (-7.724228e-02, -9.389315e-01, 3.353225e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.36168e-07, but xyz error = 0.000436905 in point (-2.030138e-01, -8.701330e-01, -4.490590e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.17016e-07, but xyz error = 0.000504729 in point (1.033491e-01, -7.477219e-01, -6.559200e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 2.89417e-07, but xyz error = 0.000480419 in point (8.676754e-02, 7.411285e-01, 6.657327e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 4.04186e-07, but xyz error = 0.000451109 in point (-5.065604e-01, -4.062913e-01, 7.604761e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.52066e-07, but xyz error = 0.000500897 in point (-7.916217e-01, -5.350497e-01, -2.950540e-01) on surface 1
# level=Warning msg=Converged at iter. 8 for initial guess (0,1) with uv error = 2.0135e-07, but xyz error = 0.000413912 in point (7.805294e-01, -3.580094e-01, -5.124482e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 4.3973e-07, but xyz error = 0.000527806 in point (-3.702720e-01, 6.919298e-01, -6.197837e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 4.0379e-07, but xyz error = 0.000522965 in point (-5.431497e-02, -6.374047e-01, -7.686125e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.99345e-07, but xyz error = 0.000440871 in point (-8.286197e-01, 4.210511e-01, -3.689247e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.2078e-07, but xyz error = 0.000347313 in point (-7.871254e-01, -5.739292e-01, -2.259178e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.03806e-07, but xyz error = 0.000391778 in point (-2.759194e-01, 8.163944e-01, -5.073152e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.95377e-07, but xyz error = 0.000403576 in point (-4.790506e-01, 5.318795e-01, 6.982942e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 3.64209e-07, but xyz error = 0.000590943 in point (5.031502e-02, 9.715900e-01, -2.312600e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 1.33254e-07, but xyz error = 0.000362863 in point (9.577037e-02, 9.841465e-01, -1.492774e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.38162e-07, but xyz error = 0.000469604 in point (-3.922298e-02, 9.558889e-01, -2.910977e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 3.51927e-07, but xyz error = 0.000542271 in point (6.135689e-01, -6.301869e-01, 4.758127e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 3.99122e-07, but xyz error = 0.000506423 in point (-7.944543e-01, 7.865829e-02, -6.022087e-01) on surface 1
# level=Warning msg=Converged at iter. 8 for initial guess (0,1) with uv error = 2.07741e-07, but xyz error = 0.000447957 in point (9.539770e-01, -1.694245e-01, -2.474334e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 3.38857e-07, but xyz error = 0.000381736 in point (2.084700e-01, -6.082997e-01, -7.658405e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.4249e-07, but xyz error = 0.000377304 in point (-6.494255e-01, 7.580449e-01, 6.012015e-02) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 4.6393e-07, but xyz error = 0.000489504 in point (-7.168302e-01, -2.663863e-02, 6.967388e-01) on surface 1
# level=Warning msg=Converged at iter. 9 for initial guess (0,2) with uv error = 2.06111e-07, but xyz error = 0.00039206 in point (7.862261e-01, 2.905374e-01, 5.453774e-01) on surface 1
# level=Warning msg=Converged at iter. 12 for initial guess (0,0) with uv error = 3.90432e-07, but xyz error = 0.000580223 in point (8.736869e-01, 3.043066e-01, 3.795638e-01) on surface 1
# level=Warning msg=Converged at iter. 9 for initial guess (0,1) with uv error = 4.56415e-07, but xyz error = 0.000625204 in point (2.135177e-01, -3.327877e-01, -9.185110e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 4.49115e-07, but xyz error = 0.000624645 in point (6.504636e-01, 6.117558e-01, -4.501688e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 4.41016e-07, but xyz error = 0.000615812 in point (3.050178e-01, 8.066541e-01, 5.062344e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.98319e-07, but xyz error = 0.000445156 in point (-7.140681e-01, -6.858538e-01, -1.403967e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 1.72638e-07, but xyz error = 0.000404334 in point (-1.539490e-02, -9.675782e-01, -2.521020e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.47142e-07, but xyz error = 0.000496851 in point (-7.503012e-01, -6.264571e-01, 2.111865e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 4.32214e-07, but xyz error = 0.000656287 in point (-7.646933e-01, -5.783201e-01, 2.842360e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 4.52201e-07, but xyz error = 0.000571124 in point (-4.238579e-01, -1.404400e-01, -8.947743e-01) on surface 1
# level=Warning msg=Converged at iter. 14 for initial guess (0,2) with uv error = 3.49578e-07, but xyz error = 0.000429461 in point (6.322258e-01, 3.518315e-01, 6.902936e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.04482e-07, but xyz error = 0.000489511 in point (6.830554e-02, -7.299302e-01, 6.801002e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 1.42419e-07, but xyz error = 0.000356501 in point (3.964521e-01, -8.268907e-01, -3.988453e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.63136e-07, but xyz error = 0.000392566 in point (-4.504315e-01, -5.964202e-01, -6.643752e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.56475e-07, but xyz error = 0.000378856 in point (-5.022861e-01, -2.269429e-01, 8.343894e-01) on surface 1
# level=Warning msg=Converged at iter. 9 for initial guess (0,2) with uv error = 1.84657e-07, but xyz error = 0.000421404 in point (9.727984e-01, -1.229974e-01, 1.963034e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 3.45918e-07, but xyz error = 0.000504026 in point (-8.272585e-01, -1.495931e-01, 5.415397e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (1,0) with uv error = 4.04379e-07, but xyz error = 0.00060169 in point (8.998948e-01, -8.439035e-02, -4.278640e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.52957e-07, but xyz error = 0.000357917 in point (-8.537689e-01, 2.183079e-01, -4.726737e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.32746e-07, but xyz error = 0.000482344 in point (3.024112e-01, 9.524851e-01, -3.632731e-02) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 2.8079e-07, but xyz error = 0.000498458 in point (-9.515260e-02, 9.302823e-01, -3.542892e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 2.26253e-07, but xyz error = 0.000451839 in point (-8.433865e-01, -3.039013e-01, 4.431064e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 1.40373e-07, but xyz error = 0.000373442 in point (-8.168234e-01, 4.901192e-01, 3.042739e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 4.38855e-07, but xyz error = 0.000553194 in point (-8.144930e-01, 1.255565e-01, 5.664246e-01) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 4.03327e-07, but xyz error = 0.000474098 in point (-7.455963e-01, 3.653588e-02, 6.653956e-01) on surface 1
# level=Warning msg=Converged at iter. 5 for initial guess (0,0) with uv error = 3.82345e-07, but xyz error = 0.000533018 in point (-2.537644e-01, 8.168352e-01, 5.180578e-01) on surface 1
# level=Warning msg=Converged at iter. 9 for initial guess (0,0) with uv error = 3.00877e-07, but xyz error = 0.000526294 in point (8.451919e-01, -2.467407e-01, 4.740988e-01) on surface 1
# level=Warning msg=Converged at iter. 6 for initial guess (0,0) with uv error = 3.05923e-07, but xyz error = 0.000552183 in point (7.549535e-01, 6.505446e-01, -8.268627e-02) on surface 1
# level=Warning msg=Converged at iter. 4 for initial guess (0,0) with uv error = 4.10105e-07, but xyz error = 0.000580733 in point (-8.326202e-01, -2.413330e-01, 4.984998e-01) on surface 1
# level=Warning msg=Converged at iter. 7 for initial guess (0,0) with uv error = 1.57223e-07, but xyz error = 0.00036106 in point (5.966650e-01, -6.435583e-01, -4.793992e-01) on surface 1
# level=Debug msg=Syncing OCC_Internals with GModel
# level=Debug msg=Sync is removing 0 model entities
# level=Debug msg=Destroying 0 entities in model
# level=Debug msg=OCCRTree found 1 matches at (6.12323e-17,0,1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (6.12323e-17,0,1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (6.12323e-17,0,1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (6.12323e-17,0,-1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (6.12323e-17,0,-1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (6.12323e-17,0,-1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0,0,1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0,0,1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0,0,1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0.5,-1.22465e-16,0) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0.5,-1.22465e-16,0) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0.5,-1.22465e-16,0) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0,0,-1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0,0,-1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0,0,-1) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCC surface 1 - new wire
# level=Debug msg=Curve 1 (1 --> 1) ori -1
# level=Debug msg=Curve 2 (2 --> 1) ori -1
# level=Debug msg=Curve 3 (2 --> 2) ori 1
# level=Debug msg=Curve 2 (2 --> 1) ori 1
# level=Debug msg=OCC surface 1 with 4 parameter bounds (0,6.28319)(-1.5708,1.5708)
# level=Debug msg=OCCRTree found 1 matches at (0,0,0) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0,0,0) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0,0,0) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCC volume 1 - new shell
# level=Debug msg=OCC volume 1 with 1 surfaces
# level=Debug msg=OCCRTree found 1 matches at (0,0,0) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0,0,0) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=OCCRTree found 1 matches at (0,0,0) in tree of size 7
# level=Debug msg=OCCRtree 0 matches after bounding box filtering
# level=Debug msg=GModel imported:
# level=Debug msg=2 points
# level=Debug msg=3 curves
# level=Debug msg=1 surfaces
# level=Debug msg=1 volumes
# level=Info msg=Meshing 1D...
# Info    : Meshing 1D...
# level=Progress msg=Meshing 1D...
# level=Progress msg=Meshing 1D...
# level=Progress msg=Meshing 1D...
# level=Info msg=Done meshing 1D (Wall 0.0807528s, CPU 0.564165s)
# Info    : Done meshing 1D (Wall 0.0807528s, CPU 0.564165s)
# level=Info msg=2 nodes 2 elements
# Info    : 2 nodes 2 elements
# level=Info msg=Meshing 2D...
# Info    : Meshing 2D...
# level=Progress msg=Meshing 2D...
# level=Info msg=Done meshing 2D (Wall 3.5775e-05s, CPU 3e-05s)
# Info    : Done meshing 2D (Wall 3.5775e-05s, CPU 3e-05s)
# level=Info msg=33 nodes 34 elements
# Info    : 33 nodes 34 elements
# level=Info msg=Meshing 3D...
# Info    : Meshing 3D...
# level=Progress msg=Meshing 3D...
# level=Info msg=3D Meshing 1 volume with 1 connected component
# Info    : 3D Meshing 1 volume with 1 connected component
# level=Info msg=Tetrahedrizing 1733 nodes...
# Info    : Tetrahedrizing 1733 nodes...
# level=Info msg=Done tetrahedrizing 1741 nodes (Wall 0.0153618s, CPU 0.075627s)
# Info    : Done tetrahedrizing 1741 nodes (Wall 0.0153618s, CPU 0.075627s)
# level=Debug msg=Points have been tetrahedralized
# Debug   : Points have been tetrahedralized
# level=Info msg=Reconstructing mesh...
# Info    : Reconstructing mesh...
# level=Info msg= - Creating surface mesh
# Info    :  - Creating surface mesh
# level=Info msg= - Identifying boundary edges
# Info    :  - Identifying boundary edges
# level=Debug msg=  3462 (5193) subfaces (segments)
# Debug   :   3462 (5193) subfaces (segments)
# level=Info msg= - Recovering boundary
# Info    :  - Recovering boundary
# level=Debug msg=Statistics:
# Debug   : Statistics:
# level=Debug msg=  Input points: 1741
# Debug   :   Input points: 1741
# level=Debug msg=  Input facets: 1
# Debug   :   Input facets: 1
# level=Debug msg=  Input segments: 0
# Debug   :   Input segments: 0
# level=Debug msg= Mesh points: 1741
# Debug   :  Mesh points: 1741
# level=Debug msg=  Mesh tetrahedra: 4993
# Debug   :   Mesh tetrahedra: 4993
# level=Debug msg=  Mesh faces: 11717
# Debug   :   Mesh faces: 11717
# level=Debug msg=  Mesh faces on facets: 3462
# Debug   :   Mesh faces on facets: 3462
# level=Debug msg=  Mesh edges on segments: 5193
# Debug   :   Mesh edges on segments: 5193
# level=Debug msg=Writing to GRegion...
# Debug   : Writing to GRegion...
# level=Info msg=Done reconstructing mesh (Wall 0.0307393s, CPU 0.099061s)
# Info    : Done reconstructing mesh (Wall 0.0307393s, CPU 0.099061s)
# level=Debug msg=start with a non classified tet
# Debug   : start with a non classified tet
# level=Debug msg=Found 4993 tets with 1 faces (Wall 0.0029429s, CPU 0.003081s)
# Debug   : Found 4993 tets with 1 faces (Wall 0.0029429s, CPU 0.003081s)
# level=Info msg=Found volume 1
# Info    : Found volume 1
# level=Debug msg=All 4993 tets were connected
# Debug   : All 4993 tets were connected
# level=Info msg=It. 0 - 0 nodes created - worst tet radius 11.3531 (nodes removed 0 0)
# Info    : It. 0 - 0 nodes created - worst tet radius 11.3531 (nodes removed 0 0)
# level=Info msg=It. 500 - 500 nodes created - worst tet radius 1.62709 (nodes removed 0 0)
# Info    : It. 500 - 500 nodes created - worst tet radius 1.62709 (nodes removed 0 0)
# level=Info msg=It. 1000 - 1000 nodes created - worst tet radius 1.3136 (nodes removed 0 0)
# Info    : It. 1000 - 1000 nodes created - worst tet radius 1.3136 (nodes removed 0 0)
# level=Info msg=It. 1500 - 1500 nodes created - worst tet radius 1.15804 (nodes removed 0 0)
# Info    : It. 1500 - 1500 nodes created - worst tet radius 1.15804 (nodes removed 0 0)
# level=Info msg=It. 2000 - 2000 nodes created - worst tet radius 1.0648 (nodes removed 0 0)
# Info    : It. 2000 - 2000 nodes created - worst tet radius 1.0648 (nodes removed 0 0)
# level=Info msg=3D refinement terminated (4167 nodes total):
# Info    : 3D refinement terminated (4167 nodes total):
# level=Info msg= - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 Delaunay cavities modified for star shapeness
# level=Info msg= - 0 nodes could not be inserted
# Info    :  - 0 nodes could not be inserted
# level=Info msg= - 20681 tetrahedra created in 0.0803929 sec. (257249 tets/s)
# Info    :  - 20681 tetrahedra created in 0.0803929 sec. (257249 tets/s)
# level=Progress msg=Meshing 3D...
# level=Info msg=Done meshing 3D (Wall 0.147302s, CPU 0.219775s)
# Info    : Done meshing 3D (Wall 0.147302s, CPU 0.219775s)
# level=Info msg=Optimizing mesh...
# Info    : Optimizing mesh...
# level=Info msg=Optimizing volume 1
# Info    : Optimizing volume 1
# level=Info msg=Optimization starts (volume = 4.17458) with worst = 0.00651662 / average = 0.764652:
# Info    : Optimization starts (volume = 4.17458) with worst = 0.00651662 / average = 0.764652:
# level=Info msg=0.00 < quality < 0.10 :        46 elements
# Info    : 0.00 < quality < 0.10 :        46 elements
# level=Info msg=0.10 < quality < 0.20 :       144 elements
# Info    : 0.10 < quality < 0.20 :       144 elements
# level=Info msg=0.20 < quality < 0.30 :       244 elements
# Info    : 0.20 < quality < 0.30 :       244 elements
# level=Info msg=0.30 < quality < 0.40 :       442 elements
# Info    : 0.30 < quality < 0.40 :       442 elements
# level=Info msg=0.40 < quality < 0.50 :       577 elements
# Info    : 0.40 < quality < 0.50 :       577 elements
# level=Info msg=0.50 < quality < 0.60 :      1144 elements
# Info    : 0.50 < quality < 0.60 :      1144 elements
# level=Info msg=0.60 < quality < 0.70 :      2564 elements
# Info    : 0.60 < quality < 0.70 :      2564 elements
# level=Info msg=0.70 < quality < 0.80 :      5084 elements
# Info    : 0.70 < quality < 0.80 :      5084 elements
# level=Info msg=0.80 < quality < 0.90 :      7132 elements
# Info    : 0.80 < quality < 0.90 :      7132 elements
# level=Info msg=0.90 < quality < 1.00 :      3304 elements
# Info    : 0.90 < quality < 1.00 :      3304 elements
# level=Info msg=428 edge swaps, 13 node relocations (volume = 4.17458): worst = 0.176636 / average = 0.778125 (Wall 0.00545125s, CPU 0.004944s)
# Info    : 428 edge swaps, 13 node relocations (volume = 4.17458): worst = 0.176636 / average = 0.778125 (Wall 0.00545125s, CPU 0.004944s)
# level=Info msg=431 edge swaps, 14 node relocations (volume = 4.17458): worst = 0.22942 / average = 0.778179 (Wall 0.00636708s, CPU 0.005975s)
# Info    : 431 edge swaps, 14 node relocations (volume = 4.17458): worst = 0.22942 / average = 0.778179 (Wall 0.00636708s, CPU 0.005975s)
# level=Info msg=No ill-shaped tets in the mesh :-)
# Info    : No ill-shaped tets in the mesh :-)
# level=Info msg=0.00 < quality < 0.10 :         0 elements
# Info    : 0.00 < quality < 0.10 :         0 elements
# level=Info msg=0.10 < quality < 0.20 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# level=Info msg=0.20 < quality < 0.30 :         1 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# level=Info msg=0.30 < quality < 0.40 :       432 elements
# Info    : 0.30 < quality < 0.40 :       432 elements
# level=Info msg=0.40 < quality < 0.50 :       539 elements
# Info    : 0.40 < quality < 0.50 :       539 elements
# level=Info msg=0.50 < quality < 0.60 :      1112 elements
# Info    : 0.50 < quality < 0.60 :      1112 elements
# level=Info msg=0.60 < quality < 0.70 :      2543 elements
# Info    : 0.60 < quality < 0.70 :      2543 elements
# level=Info msg=0.70 < quality < 0.80 :      5111 elements
# Info    : 0.70 < quality < 0.80 :      5111 elements
# level=Info msg=0.80 < quality < 0.90 :      7245 elements
# Info    : 0.80 < quality < 0.90 :      7245 elements
# level=Info msg=0.90 < quality < 1.00 :      3297 elements
# Info    : 0.90 < quality < 1.00 :      3297 elements
# level=Info msg=Done optimizing mesh (Wall 0.0184699s, CPU 0.017177s)
# Info    : Done optimizing mesh (Wall 0.0184699s, CPU 0.017177s)
# level=Info msg=4167 nodes 23776 elements
# Info    : 4167 nodes 23776 elements
# Debug   : Destroying model
# Debug   : Destroying model mesh
#
# Loaded file Mesh_1.med
# Mesh name = Mesh_1, mesh dim = 3, space dim = 3, nb cells= 20280, nb nodes= 4167
#
#  Simulation on 1 processor(s)
# Processor [0] ready for action
#
#  Diffusion problem with density 1.00e+04, specific heat 3.00e+02, conductivity 5.00e+00 and finite volumes method
#
#
#  Initialising the diffusion of a solid temperature using Finite volumes method
#
# Saving numerical results at time step number 0
#
# Running test case SolverlabDiffusionProblem
# Maximum time 0.00 reached
# End of calculation at time t = 0.00e+00 and time step number 1
# Linear solver gmres , preconditioner lu
#  Initialising the diffusion of a solid temperature using Finite volumes method
#
# Saving numerical results at time step number 0
#
# Running test case diffusion_3D
# Maximum diffusivity is 1.67e-06, CFL = 100.00, Delta x = 7.57e-03
#  Newton iteration 0, gmres iterations : 1, preconditioner : lu, variation ||Uk+1-Uk||: 1.59e+01
#  Newton iteration 1, gmres iterations : 1, preconditioner : lu, variation ||Uk+1-Uk||: 0.00e+00
# Nombre d'iterations de Newton 2, Nombre max d'iterations gmres : 1
#
# Solved time step = 1, dt = 3.44e+03, time = 3.44e+03, ||Un+1-Un||= 8.53e-01
#
# Saving numerical results at time step number 50
#
# Maximum number of time steps 50 reached
# End of calculation at time t = 1.72e+05 and time step number 51

# %%
# Create the geometry
from salome.shaper import model

model.begin()
partSet = model.moduleDocument()

Part_1 = model.addPart(partSet)
Part_1_doc = Part_1.document()

Sphere_1 = model.addSphere(Part_1_doc, model.selection("VERTEX", "PartSet/Origin"), 1)

model.end()
model.publishToShaperStudy()

import SHAPERSTUDY
Sphere_1_1, = SHAPERSTUDY.shape(model.featureStringId(Sphere_1))

# %%
# Create the mesh from the geometry
import  SMESH, SALOMEDS
from salome.smesh import smeshBuilder

smesh = smeshBuilder.New()

Mesh_1 = smesh.Mesh(Sphere_1_1,'Mesh_1')
GMSH_3D = Mesh_1.Tetrahedron(algo=smeshBuilder.GMSH_3D)
Gmsh_3D_Parameters = GMSH_3D.Parameters()
Gmsh_3D_Parameters.Set3DAlgo( 0 )
Gmsh_3D_Parameters.SetMinSize( 0.05 )
Gmsh_3D_Parameters.SetIs2d( 0 )
status = Mesh_1.RemoveHypothesis(Gmsh_3D_Parameters)
Gmsh_3D_Parameters_1 = GMSH_3D.Parameters()
Gmsh_3D_Parameters_1.Set3DAlgo( 0 )
Gmsh_3D_Parameters_1.SetMinSize( 0 )
Gmsh_3D_Parameters_1.SetSizeFactor( 0.05 )
Gmsh_3D_Parameters_1.SetIs2d( 0 )
GMSH_2D = Mesh_1.Triangle(algo=smeshBuilder.GMSH_2D)
Gmsh_Parameters = GMSH_2D.Parameters()
Gmsh_Parameters.Set2DAlgo( 0 )
Gmsh_Parameters.SetMinSize( 0 )
Gmsh_Parameters.SetMaxSize( 0.1)
Gmsh_Parameters.SetIs2d( 1 )
isDone = Mesh_1.Compute()
Mesh_1.CheckCompute()

# %%
Group_1 = Mesh_1.CreateEmptyGroup( SMESH.FACE, 'External_Face' )
nbAdd = Group_1.AddFrom( Mesh_1.GetMesh() )
[ Group_1 ] = Mesh_1.GetGroups()

smesh.SetName(Gmsh_Parameters, 'Gmsh Parameters')
smesh.SetName(Mesh_1.GetMesh(), 'Mesh_1')
smesh.SetName(Gmsh_3D_Parameters, 'Gmsh 3D Parameters')
smesh.SetName(GMSH_3D.GetAlgorithm(), 'GMSH_3D')
smesh.SetName(Gmsh_3D_Parameters_1, 'Gmsh 3D Parameters')
smesh.SetName(GMSH_2D.GetAlgorithm(), 'GMSH_2D')

try:
  Mesh_1.ExportMED( r'Mesh_1.med', 0, 41, 1, Mesh_1, 1, [], '',-1, 1 )
  pass
except:
  print('ExportPartToMED() failed. Invalid file name?')

# %% [markdown]
# ## Resolution with CoreFlows
#
# Load the MED format mesh created earlier.

# %%
# Mesh
mesh = cdmath.Mesh("Mesh_1.med")

# %% [markdown]
# We can then define the problem with the material characteristics

# %%
density = 10000
specificHeat = 300
conductivity = 5
problem = cf.DiffusionEquation(3, False, density, specificHeat, conductivity)

# %% [markdown]
# specifying that a finite volume resolution is desired (argument `False`).
# We define the initial condition, detailing the definition domain,
# the list of values to be assigned (here we have only one) and finally the mesh entity type, which here is the cell
# in the finite volume framework. If we had asked for a finite element resolution, we would have had to
# give a field to the nodes as in the previous example.

# %%
problem.setInitialFieldConstant(mesh, [15], cdmath.CELLS)

# %% [markdown]
# As far as the boundary conditions are concerned, we choose here to give a zero flow
# on the sphere's boundaries, i.e. a Neumann condition:

# %%
# Boundary conditions
problem.setNeumannBoundaryCondition("External_Face")

# %% [markdown]
# We prepare a heat source centered at the sphere's origin by traversing the mesh cells
# to assign values to the field.

# %%
# Right-hand side
heatPowerField = cdmath.Field("Heat power", cdmath.CELLS, mesh, 1)
for i in range(mesh.getNumberOfCells()):
    Ci = mesh.getCell(i)
    x = Ci.x()
    y = Ci.y()
    z = Ci.z()

    heatPowerField[i] = 1000 * exp(-10 * (x * x + y * y + z * z))

problem.setHeatPowerField(heatPowerField)
problem.initialize()
exitStatus = problem.run()
if not exitStatus:
    raise RuntimeError(f"Simulation failed")

problem.terminate()

# %% [markdown]
# We define some resolution parameters
# - implicit time scheme
# - matrix inversion algorithm
# - problem name
# - output frequency

# %%
# Resolution
problem.setTimeScheme(cf.Implicit)
problem.setLinearSolver(cf.GMRES, cf.LU, 50)

problem.setCFL(100.0)
problem.setPrecision(1e-6)
problem.setMaxNbOfTimeStep(50)
problem.setTimeMax(100000000000)
problem.setFreqSave(100)
problem.setFileName("diffusion_3D")
problem.setResultDirectory(".")

# %% [markdown]
# The resolution can then be launched:

# %%
problem.initialize()
exitStatus = problem.run()
if not exitStatus:
    raise RuntimeError(f"Simulation failed")

problem.terminate()

# %% [markdown]
# The results are automatically recorded according to the information
# and can be observed with **Salome**.

# %%
diffusionEquation_diffusion_3Dpvd = PVDReader(registrationName='DiffusionEquation_diffusion_3D.pvd', FileName='./DiffusionEquation_diffusion_3D.pvd')

# %%
animationScene1 = GetAnimationScene()
timeKeeper1 = GetTimeKeeper()
animationScene1.UpdateAnimationUsingDataTimeSteps()
renderView1 = GetActiveViewOrCreate('RenderView')
diffusionEquation_diffusion_3DpvdDisplay = Show(diffusionEquation_diffusion_3Dpvd, renderView1, 'UnstructuredGridRepresentation')
diffusionEquation_diffusion_3DpvdDisplay.Representation = 'Surface'
animationScene1.GoToLast()

# %%
renderView1.ResetCamera(False)
materialLibrary1 = GetMaterialLibrary()
renderView1.Update()
clip1 = Clip(registrationName='Clip1', Input=diffusionEquation_diffusion_3Dpvd)
clip1.ClipType.Origin = [0.0, 0.0, 0.0]
clip1.ClipType.Normal = [0.0, 0.0, 1.0]
clip1Display = Show(clip1, renderView1, 'UnstructuredGridRepresentation')
clip1Display.Representation = 'Surface'
Hide(diffusionEquation_diffusion_3Dpvd, renderView1)
renderView1.Update()
ColorBy(clip1Display, ('CELLS', 'SOLVERLAB results'))
clip1Display.RescaleTransferFunctionToDataRange(True, False)
clip1Display.SetScalarBarVisibility(renderView1, True)
sOLVERLABresultsLUT = GetColorTransferFunction('SOLVERLABresults')
sOLVERLABresultsPWF = GetOpacityTransferFunction('SOLVERLABresults')
sOLVERLABresultsTF2D = GetTransferFunction2D('SOLVERLABresults')
clip1Display.RescaleTransferFunctionToDataRange(False, True)
SetActiveSource(diffusionEquation_diffusion_3Dpvd)
HideInteractiveWidgets(proxy=clip1.ClipType)
SetActiveSource(clip1)
ShowInteractiveWidgets(proxy=clip1.ClipType)
layout1 = GetLayout()
layout1.SetSize(3056, 1115)

# %%
renderView1.CameraPosition = [4.013230503985284, 1.4341159836510837, 5.1589435816460725]
renderView1.CameraFocalPoint = [-0.00011444091796874981, -4.827976226806646e-06, -6.239227298405378e-20]
renderView1.CameraViewUp = [-0.0835939881493395, 0.9749749758733987, -0.20599961545098572]
renderView1.CameraParallelScale = 1.7319295439543239

SaveScreenshot('result.png', renderView1, ImageResolution=[3056, 1115],
    TransparentBackground=1)
# Out:
# True

# %% [markdown]
# [3D diffusion results](result.png)
